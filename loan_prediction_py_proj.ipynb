# %%
#import dependencies
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
pd.options.mode.chained_assignment = None

# %%
l_set=pd.read_csv(r'c:\Users\srini\Downloads\loan_prediction_proj.csv')
l_set
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#number of rows and colums
l_set.shape
# Out:
# (614, 13)

# %%
#statistical measure
l_set.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# number of missing values in each column
l_set.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# dropping the missing values
l_set = l_set.dropna()

# %%
l_set.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# label encoding
l_set.replace({"Loan_Status":{'N':0,'Y':1}},inplace=True)
l_set
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1    LP001003       1        1          1          1              0
# 2    LP001005       1        1          0          1              1
# 3    LP001006       1        1          0          0              0
# 4    LP001008       1        0          0          1              0
# 5    LP001011       1        1          2          1              1
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          1              0
# 610  LP002979       1        1          4          1              0
# 611  LP002983       1        1          1          1              0
# 612  LP002984       1        1          2          1              0
# 613  LP002990       0        0          0          1              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
# values of the 'Dependent' column
l_set['Dependents'].value_counts()
# Out:
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: Dependents, dtype: int64

# %%
# replacing the value of 3+ to 4
l_set = l_set.replace(to_replace='3+', value=4)

# %%
l_set
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# education vs Loan Status
sns.countplot(x='Education',hue='Loan_Status',data=l_set)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
# marital status vs Loan Status
sns.countplot(x='Married',hue='Loan_Status',data=l_set)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
# dependents & Loan Status
sns.countplot(x='Dependents',hue='Loan_Status',data=l_set)
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
# self employed vs Loan Status
sns.countplot(x='Self_Employed',hue='Loan_Status',data=l_set)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
#Property_Area vs Loan status
sns.countplot(x='Property_Area',hue='Loan_Status',data=l_set)
# Out:
# <Axes: xlabel='Property_Area', ylabel='count'>

# %%
# convert categorical columns to numerical values
l_set.replace({'Married':{'No':0,'Yes':1},'Gender':{'Male':1,'Female':0},'Self_Employed':{'No':0,'Yes':1},
                      'Property_Area':{'Rural':0,'Semiurban':1,'Urban':2},'Education':{'Graduate':1,'Not Graduate':0}},inplace=True)
l_set.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
# 5  LP001011       1        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 1             1.0              0            0
# 2             1.0              2            1
# ...

# %%
# separating the data and label
X = l_set.drop(columns=['Loan_ID','Loan_Status'],axis=1)
Y = l_set['Loan_Status']

# %%
print(X)
print(Y)
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1          1          1              0             4583
# 2         1        1          0          1              1             3000
# 3         1        1          0          0              0             2583
# 4         1        0          0          1              0             6000
# 5         1        1          2          1              1             5417
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          1              0             2900
# 610       1        1          4          1              0             4106
# 611       1        1          1          1              0             8072
# 612       1        1          2          1              0             7583
# 613       0        0          0          1              1             4583
#
# ...

# %%
X_train, X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1,stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (480, 11) (432, 11) (48, 11)

# %%
#TRAINING THE MODEL
classifier = svm.SVC(kernel='linear')

# %%
#TRAINING THE SVM
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
#MODEL EVALUATION
#accuracy score on training data
X_train_prediction = classifier.predict(X_train)
training_data_accuray = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data : ', training_data_accuray)
# Out:
# Accuracy on training data :  0.7986111111111112

# %%
# accuracy score on training data
X_test_prediction = classifier.predict(X_test)
test_data_accuray = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on test data : ', test_data_accuray)
# Out:
# Accuracy on test data :  0.8333333333333334
